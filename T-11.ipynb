# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Ranjan Yadav\AppData\Local\Temp\ipykernel_10228\3459056358.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv('users.csv')
data
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   12            19000          0
# 1   15810944    Male   11            20000          0
# 2   15668575  Female    1            43000          0
# 3   15603246  Female   27            57000          0
# 4   15804002    Male   10            76000          0
# ..       ...     ...  ...              ...        ...
# 94  15786993  Female   45            83000          0
# 95  15709441  Female   35            44000          0
# 96  15710257  Female    4            25000          0
# 97  15582492    Male    5           123000          1
# 98  15575694    Male   35            73000          0
#
# [99 rows x 5 columns]

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Purchased'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# x=data.iloc[:,:-1]
# y=data.iloc[:,-1]
# x
# Out:
#      User ID  Gender  Age  EstimatedSalary
# 0   15624510    Male   12            19000
# 1   15810944    Male   11            20000
# 2   15668575  Female    1            43000
# 3   15603246  Female   27            57000
# 4   15804002    Male   10            76000
# ..       ...     ...  ...              ...
# 94  15786993  Female   45            83000
# 95  15709441  Female   35            44000
# 96  15710257  Female    4            25000
# 97  15582492    Male    5           123000
# 98  15575694    Male   35            73000
#
# [99 rows x 4 columns]

# %%
# y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 94    0
# 95    0
# 96    0
# 97    1
# 98    0
# Name: Purchased, Length: 99, dtype: int64

# %%
X=data.columns.drop("Purchased")
y=data['Purchased']

# %%
X
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary'], dtype='object')

# %%
data_encoded=pd.get_dummies(data[X])
print("Total no. of predictors after encoding =",len(data_encoded.columns))
# Out:
# Total no. of predictors after encoding = 5

# %%
data_encoded
# Out:
#      User ID  Age  EstimatedSalary  Gender_Female  Gender_Male
# 0   15624510   12            19000          False         True
# 1   15810944   11            20000          False         True
# 2   15668575    1            43000           True        False
# 3   15603246   27            57000           True        False
# 4   15804002   10            76000          False         True
# ..       ...  ...              ...            ...          ...
# 94  15786993   45            83000           True        False
# 95  15709441   35            44000           True        False
# 96  15710257    4            25000           True        False
# 97  15582492    5           123000          False         True
# 98  15575694   35            73000          False         True
#
# [99 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_encoded,y,test_size=0.15, random_state=0)

print("Shape of X_train data: ", X_train.shape)
print("Shape of X_test data: ", X_test.shape)
print("Shape of y_train data:", y_train.shape)
print("Shape of y_test data:", y_test.shape)
# Out:
# Shape of X_train data:  (84, 5)
# Shape of X_test data:  (15, 5)
# Shape of y_train data: (84,)
# Shape of y_test data: (15,)

# %%
from sklearn.tree import  DecisionTreeClassifier
model = DecisionTreeClassifier(criterion="entropy",random_state=1)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
from sklearn.tree import export_graphviz
import graphviz

data = export_graphviz(model, out_file=None, feature_names=data_encoded.columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 2
#       1 from sklearn.tree import export_graphviz
# ----> 2 import graphviz
#       4 data = export_graphviz(model, out_file=None, feature_names=data_encoded.columns)
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
graph = graphviz.Source(data)
graph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 graph = graphviz.Source(data)
#       2 graph
#
# NameError: name 'graphviz' is not defined

# %%
model.score(X_train, y_train) * 100
# Out:
# 1.0

# %%
model.score(X_test, y_test) * 100
# Out:
# 80.0
